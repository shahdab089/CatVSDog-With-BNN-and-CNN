# %%
import tensorflow as tf
import larq as lq

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

train_images = train_images.reshape((60000, 28, 28, 1))
test_images = test_images.reshape((10000, 28, 28, 1))

# Normalize pixel values to be between -1 and 1
train_images, test_images = train_images / 127.5 - 1, test_images / 127.5 - 1

# %%
print

# %%
# All quantized layers except the first will use the same options
kwargs = dict(input_quantizer="ste_sign",
              kernel_quantizer="ste_sign",
              kernel_constraint="weight_clip")

model = tf.keras.models.Sequential()

# In the first layer we only quantize the weights and not the input
model.add(lq.layers.QuantConv2D(32, (3, 3),
                                kernel_quantizer="ste_sign",
                                kernel_constraint="weight_clip",
                                use_bias=False,
                                input_shape=(28, 28, 1)))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.BatchNormalization(scale=False))

model.add(lq.layers.QuantConv2D(64, (3, 3), use_bias=False, **kwargs))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.BatchNormalization(scale=False))

model.add(lq.layers.QuantConv2D(64, (3, 3), use_bias=False, **kwargs))
model.add(tf.keras.layers.BatchNormalization(scale=False))
model.add(tf.keras.layers.Flatten())

model.add(lq.layers.QuantDense(64, use_bias=False, **kwargs))
model.add(tf.keras.layers.BatchNormalization(scale=False))
model.add(lq.layers.QuantDense(10, use_bias=False, **kwargs))
model.add(tf.keras.layers.BatchNormalization(scale=False))
model.add(tf.keras.layers.Activation("softmax"))

# %%
lq.models.summary(model)
# Out:
# +sequential stats------------------------------------------------------------------------------------------+
# | Layer                  Input prec.           Outputs  # 1-bit  # 32-bit  Memory  1-bit MACs  32-bit MACs |
# |                              (bit)                        x 1       x 1    (kB)                          |
# +----------------------------------------------------------------------------------------------------------+
# | quant_conv2d                     -  (-1, 26, 26, 32)      288         0    0.04           0       194688 |
# | max_pooling2d                    -  (-1, 13, 13, 32)        0         0       0           0            0 |
# | batch_normalization              -  (-1, 13, 13, 32)        0        96    0.38           0            0 |
# | quant_conv2d_1                   1  (-1, 11, 11, 64)    18432         0    2.25     2230272            0 |
# | max_pooling2d_1                  -    (-1, 5, 5, 64)        0         0       0           0            0 |
# | batch_normalization_1            -    (-1, 5, 5, 64)        0       192    0.75           0            0 |
# | quant_conv2d_2                   1    (-1, 3, 3, 64)    36864         0    4.50      331776            0 |
# | batch_normalization_2            -    (-1, 3, 3, 64)        0       192    0.75           0            0 |
# | flatten                          -         (-1, 576)        0         0       0           0            0 |
# | quant_dense                      1          (-1, 64)    36864         0    4.50       36864            0 |
# | batch_normalization_3            -          (-1, 64)        0       192    0.75           0            0 |
# | quant_dense_1                    1          (-1, 10)      640         0    0.08         640            0 |
# | batch_normalization_4            -          (-1, 10)        0        30    0.12           0            0 |
# | activation                       -          (-1, 10)        0         0       0           ?            ? |
# +----------------------------------------------------------------------------------------------------------+
# | Total                                                   93088       702   14.11     2599552       194688 |
# +----------------------------------------------------------------------------------------------------------+
# +sequential summary-------------------------+
# | Total params                      93.8 k  |
# | Trainable params                  93.3 k  |
# | Non-trainable params              468     |
# | Model size:                       0.01 MB |
# | Float-32 Equivalent               0.36 MB |
# | Compression Ratio of Memory       0.04    |
# | Number of MACs                    2.79 M  |
# | Ratio of MACs that are binarized  0.9303  |
# +-------------------------------------------+

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(train_images, train_labels, batch_size=64, epochs=6)

test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# Train on 60000 samples
# Epoch 1/6
# 60000/60000 [==============================] - 44s 737us/sample - loss: 0.6470 - accuracy: 0.9085
# Epoch 2/6
# 60000/60000 [==============================] - 42s 706us/sample - loss: 0.4732 - accuracy: 0.9625
# Epoch 3/6
# 60000/60000 [==============================] - 42s 706us/sample - loss: 0.4470 - accuracy: 0.9693
# Epoch 4/6
# 60000/60000 [==============================] - 42s 706us/sample - loss: 0.4349 - accuracy: 0.9735
# Epoch 5/6
# 60000/60000 [==============================] - 42s 696us/sample - loss: 0.4314 - accuracy: 0.9752
# Epoch 6/6
# 60000/60000 [==============================] - 42s 701us/sample - loss: 0.4281 - accuracy: 0.9770- loss: 0.428 - ETA: 0s - loss: 0.4283 - accuracy
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print(f"Test accuracy {test_acc * 100:.2f} %")
# Out:
# Test accuracy 95.74 %
